# %%
pwd
# Out:
# 'D:\\'

# %%
import pandas as pd

# %%
df = pd.read_csv('mtcarsmissing.csv')
df.head()
# Out:
#                model   mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# 2         Datsun 710  22.8  NaN    NaN    NaN   NaN    NaN    NaN  1.0  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  NaN
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
#
#    gear  carb
# 0   4.0     4
# 1   4.0     4
# 2   4.0     1
# 3   3.0     1
# 4   3.0     2

# %%
df.shape
# Out:
# (32, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     29 non-null     float64
#  3   disp    30 non-null     float64
#  4   hp      30 non-null     float64
#  5   drat    31 non-null     float64
#  6   wt      30 non-null     float64
#  7   qsec    30 non-null     float64
#  8   vs      31 non-null     float64
#  9   am      31 non-null     float64
#  10  gear    31 non-null     float64
#  11  carb    32 non-null     int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      3
# disp     2
# hp       2
# drat     1
# wt       2
# qsec     2
# vs       1
# am       1
# gear     1
# carb     0
# dtype: int64

# %% [markdown]
# # Fillna

# %%
df.fillna({
    'cyl': 4,
    'hp': 150,
    'disp': 120,
    'wt': 2.0,
    'qsec': 16.0,
    'gear': 4,
    'vs':0,
    'am': 1,
    'drat': 3.9
})
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec   vs  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0
# 2            Datsun 710  22.8  4.0  120.0  150.0  3.90  2.000  16.00  1.0
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0
# 4     Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 6            Duster 360  14.3  4.0  360.0  245.0  3.21  3.570  15.84  0.0
# 7             Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00  1.0
# 8              Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90  1.0
# 9              Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.440  16.00  1.0
# 11           Merc 450SE  16.4  8.0  275.8  150.0  3.07  4.070  17.40  0.0
# ...

# %% [markdown]
# # Forward Fill

# %%
df.head()
# Out:
#                model   mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# 2         Datsun 710  22.8  NaN    NaN    NaN   NaN    NaN    NaN  1.0  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  NaN
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
#
#    gear  carb
# 0   4.0     4
# 1   4.0     4
# 2   4.0     1
# 3   3.0     1
# 4   3.0     2

# %%
df.fillna(method='ffill').head()
# Out:
#                model   mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# 2         Datsun 710  22.8  6.0  160.0  110.0  3.90  2.875  17.02  1.0  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  1.0
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
#
#    gear  carb
# 0   4.0     4
# 1   4.0     4
# 2   4.0     1
# 3   3.0     1
# 4   3.0     2

# %% [markdown]
# # Backward Fill

# %%
df.fillna(method='bfill').head()
# Out:
#                model   mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# 2         Datsun 710  22.8  6.0  258.0  110.0  3.08  3.215  19.44  1.0  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  0.0
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
#
#    gear  carb
# 0   4.0     4
# 1   4.0     4
# 2   4.0     1
# 3   3.0     1
# 4   3.0     2

# %% [markdown]
# # Replace missing data with average

# %%
df.fillna(df.mean())
# Out:
#                   model   mpg       cyl    disp          hp      drat  \
# 0             Mazda RX4  21.0  6.000000  160.00  110.000000  3.900000
# 1         Mazda RX4 Wag  21.0  6.000000  160.00  110.000000  3.900000
# 2            Datsun 710  22.8  6.275862  226.77  147.366667  3.588387
# 3        Hornet 4 Drive  21.4  6.000000  258.00  110.000000  3.080000
# 4     Hornet Sportabout  18.7  8.000000  360.00  175.000000  3.150000
# 5               Valiant  18.1  6.000000  225.00  105.000000  2.760000
# 6            Duster 360  14.3  6.275862  360.00  245.000000  3.210000
# 7             Merc 240D  24.4  4.000000  146.70   62.000000  3.690000
# 8              Merc 230  22.8  4.000000  140.80   95.000000  3.920000
# 9              Merc 280  19.2  6.000000  167.60  123.000000  3.920000
# 10            Merc 280C  17.8  6.000000  167.60  123.000000  3.920000
# 11           Merc 450SE  16.4  8.000000  275.80  147.366667  3.070000
# ...

# %% [markdown]
# # Pandas Drop

# %%
df.head()
# Out:
#                model   mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# 2         Datsun 710  22.8  NaN    NaN    NaN   NaN    NaN    NaN  1.0  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  NaN
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
#
#    gear  carb
# 0   4.0     4
# 1   4.0     4
# 2   4.0     1
# 3   3.0     1
# 4   3.0     2

# %%
df.dropna()
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec   vs  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0
# 4     Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 7             Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00  1.0
# 8              Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90  1.0
# 9              Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0
# 12           Merc 450SL  17.3  8.0  275.8  180.0  3.07  3.730  17.60  0.0
# 13          Merc 450SLC  15.2  8.0  275.8  180.0  3.07  3.780  18.00  0.0
# 15  Lincoln Continental  10.4  8.0  460.0  215.0  3.00  5.424  17.82  0.0
# 16    Chrysler Imperial  14.7  8.0  440.0  230.0  3.23  5.345  17.42  0.0
# 18          Honda Civic  30.4  4.0   75.7   52.0  4.93  1.615  18.52  1.0
# ...

# %%
df
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec   vs  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0
# 2            Datsun 710  22.8  NaN    NaN    NaN   NaN    NaN    NaN  1.0
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0
# 4     Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 6            Duster 360  14.3  NaN  360.0  245.0  3.21  3.570  15.84  NaN
# 7             Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00  1.0
# 8              Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90  1.0
# 9              Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.440    NaN  1.0
# 11           Merc 450SE  16.4  8.0  275.8    NaN  3.07  4.070  17.40  0.0
# ...

# %%
df.fillna(df.mean(), inplace=True)

# %%
df
# Out:
#                   model   mpg       cyl    disp          hp      drat  \
# 0             Mazda RX4  21.0  6.000000  160.00  110.000000  3.900000
# 1         Mazda RX4 Wag  21.0  6.000000  160.00  110.000000  3.900000
# 2            Datsun 710  22.8  6.275862  226.77  147.366667  3.588387
# 3        Hornet 4 Drive  21.4  6.000000  258.00  110.000000  3.080000
# 4     Hornet Sportabout  18.7  8.000000  360.00  175.000000  3.150000
# 5               Valiant  18.1  6.000000  225.00  105.000000  2.760000
# 6            Duster 360  14.3  6.275862  360.00  245.000000  3.210000
# 7             Merc 240D  24.4  4.000000  146.70   62.000000  3.690000
# 8              Merc 230  22.8  4.000000  140.80   95.000000  3.920000
# 9              Merc 280  19.2  6.000000  167.60  123.000000  3.920000
# 10            Merc 280C  17.8  6.000000  167.60  123.000000  3.920000
# 11           Merc 450SE  16.4  8.000000  275.80  147.366667  3.070000
# ...
