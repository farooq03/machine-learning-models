# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
x=[2017,2018,2019,2020,2021]
y=[7,10,15,30,40]

# %%
plt.plot(x,y)
plt.xticks(x)
plt.yticks(y)
plt.title('years vs turnover')
plt.xlabel('year')
plt.ylabel('turnover')
plt.show()

# %%
x_cricket=[1,2,3,4,5,6]
y_cricket=[4,5,7,8,6,5]

# %%
plt.plot(x_cricket,y_cricket)
plt.xlabel('over')
plt.ylabel('run pe over')
plt.title('runs vs over ')
plt.xticks(x_cricket)
plt.yticks(y_cricket)
plt.show()

# %%
plt.bar(x,y)
plt.title('turnover')
plt.xlabel('year')
plt.ylabel('turnover')
plt.show()

# %%
plt.bar(x_cricket,y_cricket)
plt.title('score vs over')
plt.xlabel('over')
plt.ylabel('runs')
plt.xticks(x_cricket)
plt.show()

# %%
x_math=np.arange(10)
y_math=4*x_math+5
plt.plot(x_math,y_math )

# %%
plt.bar(x_math,y_math)
plt.show()

# %%
plt.scatter(x,y)
plt.title('score vs over')
plt.xlabel('over')
plt.ylabel('runs')
plt.xticks(x)
plt.yticks(y)

plt.show()

# %%
plt.scatter(x_cricket,y_cricket)

# %%
x_comp=[2016 ,2017,2018,2019,2020,2021]
a_comp=[12,15,17,19,22,24]
b_comp=[8,16,25,30,35,22]
c_comp=[33,11,66,30,35,22]

# %%
plt.plot(x_comp,a_comp,color='red',lw=5)
plt.plot(x_comp,b_comp,color='yellow',lw=9)
plt.plot(x_comp,c_comp,color='blue')
plt.xticks(x_comp)
plt.legend(['a_comp','b_comp','c_comp'])
plt.show()

# %%
quarters=['q1','q2','q3','q4']
profit=[50,75,35,40]

# %%
plt.pie(profit,labels=quarters,autopct='%.1f',explode=[0,0,0.3,0],shadow=True)
plt.title('quarterly profit')

plt.show()

# %%
x=[1,1,22,22,3,4,5,66,6,66,1,33,4,4,6,6,6]

# %%
plt.hist(x,color='red',bins=8)
plt.title('frequency')
plt.xlabel('shoes')
plt.ylabel('no of shoes sell')

plt.show()

# %%
rcParams['figure.figsize']=(4,4)
plt.bar(over,runs)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.histplot(x,bins=8)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.lineplot(x=x,x=y)
# Out:
#   File "<ipython-input-103-159bbe8c800e>", line 1
#     sns.lineplot(x=x,x=y)
#                      ^
# SyntaxError: keyword argument repeated

# %%
sns.lineplot(x=x_cricket,y=y_cricket)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=x_cricket,y=y_cricket)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize']=(10,10)
fig, ax=plt.subplots(2,2)
ax[0,0].plot(x_cricket,y_cricket)
ax[0,0].set_title('line plot')
ax[0,1].bar(x_comp,a_comp)
ax[0,1].set_title('bar plot')
ax[1,0].pie(profit)
ax[1,0].set_title('pie profit turnover')
ax[1,1].hist(x)
ax[1,1].set_title('shoes')
plt.show()

# %%
df=pd.read_csv('mtcars.csv')
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.mpg.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='mpg'>

# %%
over=[1,2,3,4]
runs=[5,12,9,7]
sixes=[2,4,1,4]

# %%
rcParams['figure.figsize']=(5,5)
plt.plot(over,runs,color='red')
plt.plot(over,sixes)
plt.xticks(over)
#plt.yticks(runs)
plt.xlabel('overs')
plt.ylabel('per over runs')
plt.title('over vs runs')
plt.legend(['runs','sixes'])
plt.show()

# %%
rcParams['figure.figsize']=(8,8)
quarters=['a','b','c','d']
turn=[60,30,55,36]

# %%
plt.pie(turn,autopct='%0.3f',labels=quarters,explode=[0,0.4,0,0.1])

plt.show()

# %%
freq=[2,2,2,3,3,5,5,5,5]

# %%
plt.hist(freq,color='red',bins=3)
plt.show()

# %%
sns.histplot(x=freq,bins=3)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.barplot(x=over,y=runs)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=over,y=runs)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize']=(10,10)
fig,ax=plt.subplots(2,2)
ax[0,0].plot(over,runs)
ax[0,0].set_title('turnover runs')
ax[0,1].scatter(over,runs)
ax[0,1].set_title('scatter')
ax[1,0].pie(runs,autopct='%.2f',labels=over,explode=[0,0.2,0,0])
ax[1,0].set_title('turnover runs')
ax[1,1].hist(freq,bins=3)
ax[1,1].set_title('scatter')
# Out:
# Text(0.5, 1.0, 'scatter')
